# %% [markdown]
# <a href="https://colab.research.google.com/github/RNy7846/Subtipos_sanguineos/blob/main/Nova_arquitetura_de_rede.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Identificar subtipos de células sanguíneas a partir de imagens

# %% [markdown]
# Um problema importante no diagnóstico de sangue é a classificação de diferentes tipos de células sanguíneas. Aqui temos 410 imagens originais e 12.500 imagens aumentadas de células sanguíneas pareadas com rótulos de subtipo (Basófilo vs Eosinófilo vs Linfócito vs Monócito vs Neutrófilo). Queremos classificar automaticamente cada imagem de acordo com o subtipo de células dentro dela.
#
# Para obter mais informações sobre células sanguíneas e subtipos de células sanguíneas, consulte os seguintes links:
# https://www.ncbi.nlm.nih.gov/books/NBK2263/ e https://www.ncbi.nlm.nih.gov/books/NBK2263/box/A26/?report=objectonly

# %% [markdown]
# **Conectando ao Drive**

# %%
# !pip install visualkeras

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Importando Bibliotecas**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import xml.etree.ElementTree as ET
import tensorflow.keras.backend as K
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator as IDG
from tensorflow.keras.optimizers import RMSprop
from PIL import Image
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, Lambda, MaxPool2D, BatchNormalization
from keras.utils import np_utils
from random import randint
from keras.preprocessing.image import ImageDataGenerator
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from glob import glob
from distutils.dir_util import copy_tree, remove_tree
import sklearn
import itertools
import cv2
import scipy
import os
import csv

# %% [markdown]
# **Plotar os Dados**

# %%
dict_characters = {1:'NEUTROPHIL',2:'EOSINOPHIL',3:'MONOCYTE',4:'LYMPHOCYTE'}

# %% [markdown]
# **Descrever dados**

# %%
#reader = csv.reader(open('/content/drive/MyDrive/Colab Notebooks/Celulas Sanguineas/dataset2-master/dataset2-master/labels.csv'))
#next(reader)
#X3 = []
#y3 = []
#for row in reader:
#    label = row[2]
#    if len(label) > 0 and label.find(',') == -1:
#        y3.append(label)
#y3 = np.asarray(y3)
#encoder = LabelEncoder()
#encoder.fit(y3)
#encoded_y = encoder.transform(y3)
#counts = np.bincount(encoded_y)
#print(counts)
#fig, ax = plt.subplots()
#plt.bar(list(range(5)), counts)
#ax.set_xticklabels(('', 'Basophil', 'Eosinophil', 'Lymphocyte', 'Monocyte', 'Neutrophil'))
#ax.set_ylabel('Counts')

# %% [markdown]
# Aqui você pode ver que com as imagens originais temos tamanhos de turmas desequilibrados. Em vez disso, usaremos as imagens aumentadas porque elas não têm mais tamanhos de classe desequilibrados devido ao oversampling

# %%
base_dir = "/content/drive/MyDrive/Colab Notebooks/Celulas Sanguineas/dataset2-master/"
root_dir = "./"
test_dir = base_dir + "TEST/"
train_dir = base_dir + "TRAIN/"
work_dir = root_dir + "dataset/"

if os.path.exists(work_dir):
    remove_tree(work_dir)
    

os.mkdir(work_dir)
copy_tree(train_dir, work_dir)
copy_tree(test_dir, work_dir)
print("Conteudo diretorios:", os.listdir(work_dir))
# Out:
# Conteudo diretorios: ['MONOCYTE', 'EOSINOPHIL', 'NEUTROPHIL', 'LYMPHOCYTE']

# %%
numberOfClass = len(glob(train_dir+"/*")) 
print("Número de Classes: ",numberOfClass)
# Out:
# Número de Classes:  4

# %%
WORK_DIR = './dataset/'

CLASSES = [ 'MONOCYTE',
            'EOSINOPHIL',
            'NEUTROPHIL',
            'LYMPHOCYTE']

IMG_SIZE = 176
IMAGE_SIZE = [176, 176]
DIM = (IMG_SIZE, IMG_SIZE)

# %%
#Executando o aumento de imagem para ter mais amostras de dados
ZOOM = [.99, 1.01]
BRIGHT_RANGE = [0.8, 1.2]
HORZ_FLIP = True
FILL_MODE = "constant"
DATA_FORMAT = "channels_last"

work_dr = IDG(rescale = 1./255, brightness_range=BRIGHT_RANGE, zoom_range=ZOOM, data_format=DATA_FORMAT, fill_mode=FILL_MODE, horizontal_flip=HORZ_FLIP)

train_data_gen = work_dr.flow_from_directory(directory=WORK_DIR, target_size=DIM, batch_size=6500, shuffle=False)
# Out:
# Found 12436 images belonging to 4 classes.

# %%
def show_images(generator,y_pred=None):
    
    # obter labels de imagem
    labels =dict(zip([0,1,2,3], CLASSES))
    
    # obter um lote de imagens
    x,y = generator.next()
    
    # gera grade de 9 imagens
    plt.figure(figsize=(10, 10))
    if y_pred is None:
        for i in range(9):
            ax = plt.subplot(3, 3, i + 1)
            idx = randint(0, 1698)
            plt.imshow(x[idx])
            plt.axis("off")
            plt.title("Classe:{}".format(labels[np.argmax(y[idx])]))
                                                     
    else:
        for i in range(9):
            ax = plt.subplot(3, 3, i + 1)
            plt.imshow(x[i])
            plt.axis("off")
            plt.title("Actual:{} \nPredicted:{}".format(labels[np.argmax(y[i])],labels[y_pred[i]]))
    

show_images(train_data_gen)

# %%
# Recuperando os dados do iterador ImageDataGenerator
train_data, train_labels = train_data_gen.next()
# Conhecendo as dimensões do nosso conjunto de dados
print(train_data.shape, train_labels.shape)
# Out:
# (5936, 176, 176, 3) (5936, 4)

# %%
#Dividindo os dados em conjuntos de treinamento, teste e validação

train_data, test_data, train_labels, test_labels = train_test_split(train_data, train_labels, test_size = 0.2, random_state=42)
train_data, val_data, train_labels, val_labels = train_test_split(train_data, train_labels, test_size = 0.2, random_state=42)

# %% [markdown]
# **Callbacks**

# %%
def f1_score(y_true, y_pred): 
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
METRICS = [
            tf.keras.metrics.BinaryAccuracy(name='acuracia'),
            tf.keras.metrics.Precision(name='precisão'),
            tf.keras.metrics.Recall(name='recall'),  
            tf.keras.metrics.AUC(name='auc'),
            f1_score
           ]

# %%
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.01 **(epoch / s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(0.001, 5) 

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)

# %% [markdown]
# **Avaliar Modelos de Classificação**

# %%
def Train_Val_Plot(acc, val_acc, loss, val_loss, auc, val_auc,precision, val_precision, recall, val_recall, f1, val_f1):
    
    fig, (ax1, ax2, ax3, ax4, ax5, ax6) = plt.subplots(1,6, figsize= (25,6))
    fig.suptitle(" Metricas do modelo ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('Acuracia')
    ax1.set_xlabel('Época')
    ax1.set_ylabel('Acuracia')
    ax1.legend(['Treino', 'Teste'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('Loss')
    ax2.set_xlabel('Época')
    ax2.set_ylabel('Loss')
    ax1.legend(['Treino', 'Teste'])
    
    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('AUC')
    ax3.set_xlabel('Época')
    ax3.set_ylabel('AUC')
    ax1.legend(['Treino', 'Teste'])
    
    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('Precisão')
    ax4.set_xlabel('Época')
    ax4.set_ylabel('Precisão')
    ax1.legend(['Treino', 'Teste'])

    ax5.plot(range(1, len(f1) + 1), f1)
    ax5.plot(range(1, len(val_f1) + 1), val_f1)
    ax5.set_title('Recall')
    ax5.set_xlabel('Época')
    ax5.set_ylabel('Recall')
    ax1.legend(['Treino', 'Teste'])
    
    ax6.plot(range(1, len(f1) + 1), f1)
    ax6.plot(range(1, len(val_f1) + 1), val_f1)
    ax6.set_title('F1-score')
    ax6.set_xlabel('Época')
    ax6.set_ylabel('F1-score')
    ax1.legend(['Treino', 'Teste'])


    plt.show()

# %%
#CRIANDO MODELO
input_shape = (176, 176, 3)
model = Sequential()

model.add(Conv2D(256, kernel_size=(3, 3), activation='relu', input_shape=input_shape, strides=1))

model.add(Conv2D(128, (3,3)))

model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(128, (3,3)))

model.add(Conv2D(64, (3,3)))

model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64, (3,3)))

model.add(Conv2D(32, (3,3)))

model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64, (3,3)))

model.add(Conv2D(32, (3,3)))

model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Dropout(0.5))

model.add(Conv2D(64, (3,3)))

model.add(Conv2D(32, (3,3)))

model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Dropout(0.5))

model.add(Flatten())

model.add(Sequential())
model.add(Sequential())
model.add(Sequential())

model.add(Dense(numberOfClass, activation='softmax'))



#COMPILANDO MODELO
model.compile(optimizer='rmsprop',
            loss=tf.losses.CategoricalCrossentropy(),
            metrics=METRICS)

history = model.fit(train_data,
        train_labels,
        validation_data= (val_data, val_labels),
        epochs = 100,
        verbose = 1,
        callbacks=lr_scheduler
                    )

score = model.evaluate(test_data,test_labels, verbose=0)
print('\nKeras CNN #1C - acuracia:', score[1],'\n')
# Out:
# Epoch 1/150
# 65/65 [==============================] - 101s 1s/step - loss: 1.2280 - acuracia: 0.7531 - precisão: 0.5077 - recall: 0.4073 - auc: 0.7713 - f1_score: 0.4528 - val_loss: 31.5267 - val_acuracia: 0.5000 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.3328 - val_f1_score: 0.0000e+00 - lr: 0.0010
# Epoch 2/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.9646 - acuracia: 0.7658 - precisão: 0.5358 - recall: 0.4726 - auc: 0.8315 - f1_score: 0.5023 - val_loss: 4.9553 - val_acuracia: 0.7232 - val_precisão: 0.4463 - val_recall: 0.4463 - val_auc: 0.6116 - val_f1_score: 0.4464 - lr: 3.9811e-04
# Epoch 3/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.8543 - acuracia: 0.7867 - precisão: 0.5799 - recall: 0.5332 - auc: 0.8606 - f1_score: 0.5538 - val_loss: 1.9074 - val_acuracia: 0.7768 - val_precisão: 0.5537 - val_recall: 0.5537 - val_auc: 0.7772 - val_f1_score: 0.5536 - lr: 1.5849e-04
# Epoch 4/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.8194 - acuracia: 0.8036 - precisão: 0.6141 - recall: 0.5766 - auc: 0.8748 - f1_score: 0.5949 - val_loss: 1.5576 - val_acuracia: 0.7261 - val_precisão: 0.4517 - val_recall: 0.4484 - val_auc: 0.7404 - val_f1_score: 0.4500 - lr: 6.3096e-05
# Epoch 5/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7955 - acuracia: 0.8145 - precisão: 0.6369 - recall: 0.6003 - auc: 0.8827 - f1_score: 0.6180 - val_loss: 0.7908 - val_acuracia: 0.8145 - val_precisão: 0.6400 - val_recall: 0.5895 - val_auc: 0.8885 - val_f1_score: 0.6134 - lr: 2.5119e-05
# Epoch 6/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7922 - acuracia: 0.8131 - precisão: 0.6344 - recall: 0.5961 - auc: 0.8809 - f1_score: 0.6145 - val_loss: 1.1873 - val_acuracia: 0.7355 - val_precisão: 0.4704 - val_recall: 0.4600 - val_auc: 0.8286 - val_f1_score: 0.4654 - lr: 1.0000e-05
# Epoch 7/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7908 - acuracia: 0.8052 - precisão: 0.6164 - recall: 0.5843 - auc: 0.8810 - f1_score: 0.5986 - val_loss: 0.8648 - val_acuracia: 0.7689 - val_precisão: 0.5423 - val_recall: 0.4863 - val_auc: 0.8696 - val_f1_score: 0.5125 - lr: 3.9811e-06
# Epoch 8/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7791 - acuracia: 0.8122 - precisão: 0.6311 - recall: 0.5990 - auc: 0.8839 - f1_score: 0.6136 - val_loss: 0.6859 - val_acuracia: 0.8384 - val_precisão: 0.7165 - val_recall: 0.5853 - val_auc: 0.9165 - val_f1_score: 0.6406 - lr: 1.5849e-06
# Epoch 9/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7831 - acuracia: 0.8145 - precisão: 0.6361 - recall: 0.6029 - auc: 0.8844 - f1_score: 0.6178 - val_loss: 0.7020 - val_acuracia: 0.8305 - val_precisão: 0.6942 - val_recall: 0.5758 - val_auc: 0.9090 - val_f1_score: 0.6274 - lr: 6.3096e-07
# Epoch 10/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7972 - acuracia: 0.8090 - precisão: 0.6239 - recall: 0.5940 - auc: 0.8799 - f1_score: 0.6082 - val_loss: 0.6855 - val_acuracia: 0.8382 - val_precisão: 0.7107 - val_recall: 0.5947 - val_auc: 0.9146 - val_f1_score: 0.6452 - lr: 2.5119e-07
# Epoch 11/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.8033 - acuracia: 0.8068 - precisão: 0.6196 - recall: 0.5885 - auc: 0.8786 - f1_score: 0.6038 - val_loss: 0.6757 - val_acuracia: 0.8408 - val_precisão: 0.7175 - val_recall: 0.5989 - val_auc: 0.9181 - val_f1_score: 0.6496 - lr: 1.0000e-07
# Epoch 12/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7897 - acuracia: 0.8124 - precisão: 0.6325 - recall: 0.5958 - auc: 0.8831 - f1_score: 0.6126 - val_loss: 0.6723 - val_acuracia: 0.8403 - val_precisão: 0.7157 - val_recall: 0.5989 - val_auc: 0.9189 - val_f1_score: 0.6489 - lr: 3.9811e-08
# Epoch 13/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7942 - acuracia: 0.8086 - precisão: 0.6245 - recall: 0.5877 - auc: 0.8806 - f1_score: 0.6041 - val_loss: 0.6704 - val_acuracia: 0.8418 - val_precisão: 0.7206 - val_recall: 0.6000 - val_auc: 0.9197 - val_f1_score: 0.6514 - lr: 1.5849e-08
# Epoch 14/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7765 - acuracia: 0.8200 - precisão: 0.6484 - recall: 0.6114 - auc: 0.8862 - f1_score: 0.6279 - val_loss: 0.6697 - val_acuracia: 0.8416 - val_precisão: 0.7203 - val_recall: 0.5989 - val_auc: 0.9200 - val_f1_score: 0.6507 - lr: 6.3096e-09
# Epoch 15/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7914 - acuracia: 0.8096 - precisão: 0.6265 - recall: 0.5906 - auc: 0.8804 - f1_score: 0.6089 - val_loss: 0.6695 - val_acuracia: 0.8408 - val_precisão: 0.7186 - val_recall: 0.5968 - val_auc: 0.9202 - val_f1_score: 0.6486 - lr: 2.5119e-09
# Epoch 16/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7942 - acuracia: 0.8042 - precisão: 0.6151 - recall: 0.5790 - auc: 0.8798 - f1_score: 0.5979 - val_loss: 0.6692 - val_acuracia: 0.8408 - val_precisão: 0.7186 - val_recall: 0.5968 - val_auc: 0.9203 - val_f1_score: 0.6486 - lr: 1.0000e-09
# Epoch 17/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7992 - acuracia: 0.8043 - precisão: 0.6152 - recall: 0.5800 - auc: 0.8798 - f1_score: 0.5971 - val_loss: 0.6685 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9204 - val_f1_score: 0.6495 - lr: 3.9811e-10
# Epoch 18/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.8008 - acuracia: 0.8104 - precisão: 0.6286 - recall: 0.5908 - auc: 0.8802 - f1_score: 0.6106 - val_loss: 0.6682 - val_acuracia: 0.8413 - val_precisão: 0.7199 - val_recall: 0.5979 - val_auc: 0.9205 - val_f1_score: 0.6499 - lr: 1.5849e-10
# Epoch 19/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7854 - acuracia: 0.8117 - precisão: 0.6307 - recall: 0.5958 - auc: 0.8826 - f1_score: 0.6111 - val_loss: 0.6681 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9206 - val_f1_score: 0.6496 - lr: 6.3096e-11
# Epoch 20/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7938 - acuracia: 0.8112 - precisão: 0.6288 - recall: 0.5969 - auc: 0.8819 - f1_score: 0.6115 - val_loss: 0.6680 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9206 - val_f1_score: 0.6496 - lr: 2.5119e-11
# Epoch 21/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7572 - acuracia: 0.8158 - precisão: 0.6394 - recall: 0.6032 - auc: 0.8894 - f1_score: 0.6218 - val_loss: 0.6683 - val_acuracia: 0.8408 - val_precisão: 0.7186 - val_recall: 0.5968 - val_auc: 0.9205 - val_f1_score: 0.6488 - lr: 1.0000e-11
# Epoch 22/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7833 - acuracia: 0.8119 - precisão: 0.6316 - recall: 0.5940 - auc: 0.8833 - f1_score: 0.6105 - val_loss: 0.6677 - val_acuracia: 0.8405 - val_precisão: 0.7177 - val_recall: 0.5968 - val_auc: 0.9206 - val_f1_score: 0.6484 - lr: 3.9811e-12
# Epoch 23/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7673 - acuracia: 0.8132 - precisão: 0.6335 - recall: 0.5998 - auc: 0.8865 - f1_score: 0.6158 - val_loss: 0.6689 - val_acuracia: 0.8411 - val_precisão: 0.7195 - val_recall: 0.5968 - val_auc: 0.9205 - val_f1_score: 0.6491 - lr: 1.5849e-12
# Epoch 24/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.8047 - acuracia: 0.8071 - precisão: 0.6205 - recall: 0.5879 - auc: 0.8790 - f1_score: 0.6026 - val_loss: 0.6690 - val_acuracia: 0.8413 - val_precisão: 0.7199 - val_recall: 0.5979 - val_auc: 0.9204 - val_f1_score: 0.6499 - lr: 6.3096e-13
# Epoch 25/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7871 - acuracia: 0.8116 - precisão: 0.6309 - recall: 0.5940 - auc: 0.8826 - f1_score: 0.6119 - val_loss: 0.6693 - val_acuracia: 0.8411 - val_precisão: 0.7195 - val_recall: 0.5968 - val_auc: 0.9203 - val_f1_score: 0.6491 - lr: 2.5119e-13
# Epoch 26/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7948 - acuracia: 0.8104 - precisão: 0.6266 - recall: 0.5977 - auc: 0.8816 - f1_score: 0.6129 - val_loss: 0.6691 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9204 - val_f1_score: 0.6496 - lr: 1.0000e-13
# Epoch 27/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7875 - acuracia: 0.8100 - precisão: 0.6271 - recall: 0.5916 - auc: 0.8834 - f1_score: 0.6083 - val_loss: 0.6688 - val_acuracia: 0.8413 - val_precisão: 0.7199 - val_recall: 0.5979 - val_auc: 0.9204 - val_f1_score: 0.6499 - lr: 3.9811e-14
# Epoch 28/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7775 - acuracia: 0.8125 - precisão: 0.6327 - recall: 0.5956 - auc: 0.8846 - f1_score: 0.6132 - val_loss: 0.6685 - val_acuracia: 0.8408 - val_precisão: 0.7181 - val_recall: 0.5979 - val_auc: 0.9204 - val_f1_score: 0.6492 - lr: 1.5849e-14
# Epoch 29/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7903 - acuracia: 0.8140 - precisão: 0.6349 - recall: 0.6022 - auc: 0.8834 - f1_score: 0.6193 - val_loss: 0.6688 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9203 - val_f1_score: 0.6495 - lr: 6.3096e-15
# Epoch 30/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7920 - acuracia: 0.8115 - precisão: 0.6301 - recall: 0.5961 - auc: 0.8819 - f1_score: 0.6113 - val_loss: 0.6688 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9203 - val_f1_score: 0.6495 - lr: 2.5119e-15
# Epoch 31/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7936 - acuracia: 0.8100 - precisão: 0.6268 - recall: 0.5929 - auc: 0.8811 - f1_score: 0.6098 - val_loss: 0.6687 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9203 - val_f1_score: 0.6495 - lr: 1.0000e-15
# Epoch 32/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7840 - acuracia: 0.8085 - precisão: 0.6247 - recall: 0.5856 - auc: 0.8824 - f1_score: 0.6046 - val_loss: 0.6683 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9204 - val_f1_score: 0.6495 - lr: 3.9811e-16
# Epoch 33/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.8010 - acuracia: 0.8050 - precisão: 0.6156 - recall: 0.5853 - auc: 0.8802 - f1_score: 0.6008 - val_loss: 0.6688 - val_acuracia: 0.8413 - val_precisão: 0.7199 - val_recall: 0.5979 - val_auc: 0.9204 - val_f1_score: 0.6499 - lr: 1.5849e-16
# Epoch 34/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7857 - acuracia: 0.8152 - precisão: 0.6379 - recall: 0.6035 - auc: 0.8828 - f1_score: 0.6201 - val_loss: 0.6687 - val_acuracia: 0.8408 - val_precisão: 0.7186 - val_recall: 0.5968 - val_auc: 0.9206 - val_f1_score: 0.6487 - lr: 6.3096e-17
# Epoch 35/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7847 - acuracia: 0.8130 - precisão: 0.6325 - recall: 0.6014 - auc: 0.8844 - f1_score: 0.6167 - val_loss: 0.6684 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9205 - val_f1_score: 0.6496 - lr: 2.5119e-17
# Epoch 36/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7913 - acuracia: 0.8094 - precisão: 0.6257 - recall: 0.5919 - auc: 0.8813 - f1_score: 0.6093 - val_loss: 0.6685 - val_acuracia: 0.8408 - val_precisão: 0.7186 - val_recall: 0.5968 - val_auc: 0.9206 - val_f1_score: 0.6488 - lr: 1.0000e-17
# Epoch 37/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7991 - acuracia: 0.8048 - precisão: 0.6162 - recall: 0.5816 - auc: 0.8786 - f1_score: 0.5974 - val_loss: 0.6687 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9205 - val_f1_score: 0.6496 - lr: 3.9811e-18
# Epoch 38/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7955 - acuracia: 0.8108 - precisão: 0.6294 - recall: 0.5916 - auc: 0.8814 - f1_score: 0.6101 - val_loss: 0.6692 - val_acuracia: 0.8413 - val_precisão: 0.7199 - val_recall: 0.5979 - val_auc: 0.9203 - val_f1_score: 0.6499 - lr: 1.5849e-18
# Epoch 39/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7854 - acuracia: 0.8125 - precisão: 0.6317 - recall: 0.5998 - auc: 0.8838 - f1_score: 0.6148 - val_loss: 0.6692 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9203 - val_f1_score: 0.6496 - lr: 6.3096e-19
# Epoch 40/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.8048 - acuracia: 0.8096 - precisão: 0.6269 - recall: 0.5887 - auc: 0.8798 - f1_score: 0.6073 - val_loss: 0.6687 - val_acuracia: 0.8405 - val_precisão: 0.7183 - val_recall: 0.5958 - val_auc: 0.9206 - val_f1_score: 0.6479 - lr: 2.5119e-19
# Epoch 41/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7916 - acuracia: 0.8086 - precisão: 0.6231 - recall: 0.5929 - auc: 0.8805 - f1_score: 0.6086 - val_loss: 0.6687 - val_acuracia: 0.8408 - val_precisão: 0.7186 - val_recall: 0.5968 - val_auc: 0.9206 - val_f1_score: 0.6488 - lr: 1.0000e-19
# Epoch 42/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7919 - acuracia: 0.8145 - precisão: 0.6367 - recall: 0.6008 - auc: 0.8825 - f1_score: 0.6187 - val_loss: 0.6689 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9205 - val_f1_score: 0.6496 - lr: 3.9811e-20
# Epoch 43/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7983 - acuracia: 0.8099 - precisão: 0.6269 - recall: 0.5919 - auc: 0.8810 - f1_score: 0.6095 - val_loss: 0.6685 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9205 - val_f1_score: 0.6496 - lr: 1.5849e-20
# Epoch 44/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7634 - acuracia: 0.8198 - precisão: 0.6475 - recall: 0.6127 - auc: 0.8889 - f1_score: 0.6315 - val_loss: 0.6686 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9205 - val_f1_score: 0.6496 - lr: 6.3096e-21
# Epoch 45/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7953 - acuracia: 0.8118 - precisão: 0.6318 - recall: 0.5927 - auc: 0.8821 - f1_score: 0.6121 - val_loss: 0.6694 - val_acuracia: 0.8411 - val_precisão: 0.7195 - val_recall: 0.5968 - val_auc: 0.9204 - val_f1_score: 0.6491 - lr: 2.5119e-21
# Epoch 46/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7910 - acuracia: 0.8065 - precisão: 0.6193 - recall: 0.5869 - auc: 0.8803 - f1_score: 0.6019 - val_loss: 0.6693 - val_acuracia: 0.8413 - val_precisão: 0.7199 - val_recall: 0.5979 - val_auc: 0.9203 - val_f1_score: 0.6499 - lr: 1.0000e-21
# Epoch 47/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7985 - acuracia: 0.8094 - precisão: 0.6262 - recall: 0.5900 - auc: 0.8797 - f1_score: 0.6070 - val_loss: 0.6683 - val_acuracia: 0.8408 - val_precisão: 0.7186 - val_recall: 0.5968 - val_auc: 0.9206 - val_f1_score: 0.6488 - lr: 3.9811e-22
# Epoch 48/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7849 - acuracia: 0.8151 - precisão: 0.6370 - recall: 0.6053 - auc: 0.8843 - f1_score: 0.6226 - val_loss: 0.6685 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9204 - val_f1_score: 0.6495 - lr: 1.5849e-22
# Epoch 49/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7854 - acuracia: 0.8096 - precisão: 0.6263 - recall: 0.5916 - auc: 0.8822 - f1_score: 0.6081 - val_loss: 0.6682 - val_acuracia: 0.8408 - val_precisão: 0.7192 - val_recall: 0.5958 - val_auc: 0.9206 - val_f1_score: 0.6484 - lr: 6.3096e-23
# Epoch 50/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7995 - acuracia: 0.8090 - precisão: 0.6245 - recall: 0.5916 - auc: 0.8794 - f1_score: 0.6065 - val_loss: 0.6681 - val_acuracia: 0.8411 - val_precisão: 0.7195 - val_recall: 0.5968 - val_auc: 0.9206 - val_f1_score: 0.6490 - lr: 2.5119e-23
# Epoch 51/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7967 - acuracia: 0.7998 - precisão: 0.6054 - recall: 0.5716 - auc: 0.8781 - f1_score: 0.5896 - val_loss: 0.6685 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9205 - val_f1_score: 0.6496 - lr: 1.0000e-23
# Epoch 52/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7818 - acuracia: 0.8090 - precisão: 0.6242 - recall: 0.5935 - auc: 0.8829 - f1_score: 0.6090 - val_loss: 0.6678 - val_acuracia: 0.8408 - val_precisão: 0.7186 - val_recall: 0.5968 - val_auc: 0.9207 - val_f1_score: 0.6488 - lr: 3.9811e-24
# Epoch 53/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7986 - acuracia: 0.8071 - precisão: 0.6215 - recall: 0.5840 - auc: 0.8805 - f1_score: 0.6022 - val_loss: 0.6684 - val_acuracia: 0.8408 - val_precisão: 0.7186 - val_recall: 0.5968 - val_auc: 0.9206 - val_f1_score: 0.6488 - lr: 1.5849e-24
# Epoch 54/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7898 - acuracia: 0.8106 - precisão: 0.6293 - recall: 0.5900 - auc: 0.8820 - f1_score: 0.6068 - val_loss: 0.6685 - val_acuracia: 0.8411 - val_precisão: 0.7195 - val_recall: 0.5968 - val_auc: 0.9205 - val_f1_score: 0.6491 - lr: 6.3096e-25
# Epoch 55/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.8007 - acuracia: 0.8103 - precisão: 0.6276 - recall: 0.5932 - auc: 0.8793 - f1_score: 0.6096 - val_loss: 0.6686 - val_acuracia: 0.8413 - val_precisão: 0.7199 - val_recall: 0.5979 - val_auc: 0.9205 - val_f1_score: 0.6499 - lr: 2.5119e-25
# Epoch 56/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7915 - acuracia: 0.8121 - precisão: 0.6312 - recall: 0.5974 - auc: 0.8827 - f1_score: 0.6140 - val_loss: 0.6687 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9205 - val_f1_score: 0.6496 - lr: 1.0000e-25
# Epoch 57/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7967 - acuracia: 0.8068 - precisão: 0.6204 - recall: 0.5853 - auc: 0.8804 - f1_score: 0.6001 - val_loss: 0.6682 - val_acuracia: 0.8408 - val_precisão: 0.7186 - val_recall: 0.5968 - val_auc: 0.9206 - val_f1_score: 0.6488 - lr: 3.9811e-26
# Epoch 58/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7917 - acuracia: 0.8114 - precisão: 0.6297 - recall: 0.5964 - auc: 0.8817 - f1_score: 0.6138 - val_loss: 0.6681 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9205 - val_f1_score: 0.6496 - lr: 1.5849e-26
# Epoch 59/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.8023 - acuracia: 0.8098 - precisão: 0.6272 - recall: 0.5895 - auc: 0.8793 - f1_score: 0.6087 - val_loss: 0.6678 - val_acuracia: 0.8405 - val_precisão: 0.7177 - val_recall: 0.5968 - val_auc: 0.9206 - val_f1_score: 0.6484 - lr: 6.3096e-27
# Epoch 60/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7764 - acuracia: 0.8089 - precisão: 0.6254 - recall: 0.5877 - auc: 0.8829 - f1_score: 0.6064 - val_loss: 0.6686 - val_acuracia: 0.8413 - val_precisão: 0.7199 - val_recall: 0.5979 - val_auc: 0.9204 - val_f1_score: 0.6499 - lr: 2.5119e-27
# Epoch 61/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7915 - acuracia: 0.8139 - precisão: 0.6350 - recall: 0.6011 - auc: 0.8825 - f1_score: 0.6173 - val_loss: 0.6689 - val_acuracia: 0.8408 - val_precisão: 0.7186 - val_recall: 0.5968 - val_auc: 0.9202 - val_f1_score: 0.6486 - lr: 1.0000e-27
# Epoch 62/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7867 - acuracia: 0.8119 - precisão: 0.6307 - recall: 0.5979 - auc: 0.8828 - f1_score: 0.6124 - val_loss: 0.6687 - val_acuracia: 0.8408 - val_precisão: 0.7181 - val_recall: 0.5979 - val_auc: 0.9204 - val_f1_score: 0.6492 - lr: 3.9811e-28
# Epoch 63/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7802 - acuracia: 0.8110 - precisão: 0.6290 - recall: 0.5945 - auc: 0.8840 - f1_score: 0.6116 - val_loss: 0.6690 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9202 - val_f1_score: 0.6495 - lr: 1.5849e-28
# Epoch 64/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7955 - acuracia: 0.8082 - precisão: 0.6233 - recall: 0.5882 - auc: 0.8806 - f1_score: 0.6057 - val_loss: 0.6690 - val_acuracia: 0.8408 - val_precisão: 0.7186 - val_recall: 0.5968 - val_auc: 0.9203 - val_f1_score: 0.6486 - lr: 6.3096e-29
# Epoch 65/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7816 - acuracia: 0.8091 - precisão: 0.6248 - recall: 0.5919 - auc: 0.8839 - f1_score: 0.6060 - val_loss: 0.6686 - val_acuracia: 0.8413 - val_precisão: 0.7199 - val_recall: 0.5979 - val_auc: 0.9205 - val_f1_score: 0.6499 - lr: 2.5119e-29
# Epoch 66/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7800 - acuracia: 0.8093 - precisão: 0.6248 - recall: 0.5940 - auc: 0.8832 - f1_score: 0.6088 - val_loss: 0.6682 - val_acuracia: 0.8408 - val_precisão: 0.7186 - val_recall: 0.5968 - val_auc: 0.9205 - val_f1_score: 0.6488 - lr: 1.0000e-29
# Epoch 67/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7813 - acuracia: 0.8073 - precisão: 0.6207 - recall: 0.5895 - auc: 0.8824 - f1_score: 0.6037 - val_loss: 0.6687 - val_acuracia: 0.8408 - val_precisão: 0.7186 - val_recall: 0.5968 - val_auc: 0.9203 - val_f1_score: 0.6486 - lr: 3.9811e-30
# Epoch 68/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7752 - acuracia: 0.8169 - precisão: 0.6419 - recall: 0.6051 - auc: 0.8860 - f1_score: 0.6224 - val_loss: 0.6688 - val_acuracia: 0.8408 - val_precisão: 0.7186 - val_recall: 0.5968 - val_auc: 0.9203 - val_f1_score: 0.6486 - lr: 1.5849e-30
# Epoch 69/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7956 - acuracia: 0.8061 - precisão: 0.6185 - recall: 0.5853 - auc: 0.8798 - f1_score: 0.5996 - val_loss: 0.6685 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9204 - val_f1_score: 0.6495 - lr: 6.3096e-31
# Epoch 70/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7943 - acuracia: 0.8135 - precisão: 0.6335 - recall: 0.6029 - auc: 0.8824 - f1_score: 0.6179 - val_loss: 0.6688 - val_acuracia: 0.8405 - val_precisão: 0.7183 - val_recall: 0.5958 - val_auc: 0.9204 - val_f1_score: 0.6478 - lr: 2.5119e-31
# Epoch 71/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.8044 - acuracia: 0.8044 - precisão: 0.6151 - recall: 0.5811 - auc: 0.8781 - f1_score: 0.5958 - val_loss: 0.6689 - val_acuracia: 0.8413 - val_precisão: 0.7205 - val_recall: 0.5968 - val_auc: 0.9205 - val_f1_score: 0.6493 - lr: 1.0000e-31
# Epoch 72/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7803 - acuracia: 0.8079 - precisão: 0.6220 - recall: 0.5906 - auc: 0.8830 - f1_score: 0.6060 - val_loss: 0.6692 - val_acuracia: 0.8411 - val_precisão: 0.7195 - val_recall: 0.5968 - val_auc: 0.9205 - val_f1_score: 0.6491 - lr: 3.9811e-32
# Epoch 73/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7698 - acuracia: 0.8115 - precisão: 0.6306 - recall: 0.5937 - auc: 0.8860 - f1_score: 0.6108 - val_loss: 0.6691 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9205 - val_f1_score: 0.6496 - lr: 1.5849e-32
# Epoch 74/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7891 - acuracia: 0.8099 - precisão: 0.6269 - recall: 0.5919 - auc: 0.8823 - f1_score: 0.6085 - val_loss: 0.6687 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9205 - val_f1_score: 0.6496 - lr: 6.3096e-33
# Epoch 75/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7917 - acuracia: 0.8059 - precisão: 0.6181 - recall: 0.5850 - auc: 0.8806 - f1_score: 0.6031 - val_loss: 0.6685 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9205 - val_f1_score: 0.6496 - lr: 2.5119e-33
# Epoch 76/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.8053 - acuracia: 0.8098 - precisão: 0.6267 - recall: 0.5911 - auc: 0.8792 - f1_score: 0.6103 - val_loss: 0.6682 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9206 - val_f1_score: 0.6496 - lr: 1.0000e-33
# Epoch 77/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7872 - acuracia: 0.8101 - precisão: 0.6268 - recall: 0.5940 - auc: 0.8814 - f1_score: 0.6104 - val_loss: 0.6685 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9205 - val_f1_score: 0.6496 - lr: 3.9811e-34
# Epoch 78/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.8037 - acuracia: 0.8073 - precisão: 0.6213 - recall: 0.5872 - auc: 0.8783 - f1_score: 0.6041 - val_loss: 0.6683 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9204 - val_f1_score: 0.6495 - lr: 1.5849e-34
# Epoch 79/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.8079 - acuracia: 0.8092 - precisão: 0.6248 - recall: 0.5924 - auc: 0.8790 - f1_score: 0.6077 - val_loss: 0.6686 - val_acuracia: 0.8408 - val_precisão: 0.7186 - val_recall: 0.5968 - val_auc: 0.9204 - val_f1_score: 0.6486 - lr: 6.3096e-35
# Epoch 80/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7784 - acuracia: 0.8140 - precisão: 0.6350 - recall: 0.6024 - auc: 0.8852 - f1_score: 0.6188 - val_loss: 0.6691 - val_acuracia: 0.8408 - val_precisão: 0.7186 - val_recall: 0.5968 - val_auc: 0.9202 - val_f1_score: 0.6486 - lr: 2.5119e-35
# Epoch 81/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.8028 - acuracia: 0.8052 - precisão: 0.6163 - recall: 0.5848 - auc: 0.8788 - f1_score: 0.5999 - val_loss: 0.6695 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9201 - val_f1_score: 0.6495 - lr: 1.0000e-35
# Epoch 82/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7881 - acuracia: 0.8130 - precisão: 0.6329 - recall: 0.6001 - auc: 0.8835 - f1_score: 0.6169 - val_loss: 0.6693 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9202 - val_f1_score: 0.6495 - lr: 3.9811e-36
# Epoch 83/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7991 - acuracia: 0.8097 - precisão: 0.6259 - recall: 0.5937 - auc: 0.8802 - f1_score: 0.6079 - val_loss: 0.6689 - val_acuracia: 0.8413 - val_precisão: 0.7199 - val_recall: 0.5979 - val_auc: 0.9204 - val_f1_score: 0.6499 - lr: 1.5849e-36
# Epoch 84/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7896 - acuracia: 0.8093 - precisão: 0.6247 - recall: 0.5943 - auc: 0.8821 - f1_score: 0.6084 - val_loss: 0.6686 - val_acuracia: 0.8411 - val_precisão: 0.7195 - val_recall: 0.5968 - val_auc: 0.9205 - val_f1_score: 0.6491 - lr: 6.3096e-37
# Epoch 85/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7850 - acuracia: 0.8083 - precisão: 0.6227 - recall: 0.5919 - auc: 0.8834 - f1_score: 0.6059 - val_loss: 0.6683 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9204 - val_f1_score: 0.6496 - lr: 2.5119e-37
# Epoch 86/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7760 - acuracia: 0.8111 - precisão: 0.6286 - recall: 0.5972 - auc: 0.8841 - f1_score: 0.6134 - val_loss: 0.6686 - val_acuracia: 0.8413 - val_precisão: 0.7199 - val_recall: 0.5979 - val_auc: 0.9204 - val_f1_score: 0.6499 - lr: 1.0000e-37
# Epoch 87/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7772 - acuracia: 0.8088 - precisão: 0.6230 - recall: 0.5956 - auc: 0.8850 - f1_score: 0.6095 - val_loss: 0.6685 - val_acuracia: 0.8408 - val_precisão: 0.7186 - val_recall: 0.5968 - val_auc: 0.9204 - val_f1_score: 0.6486 - lr: 3.9811e-38
# Epoch 88/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7939 - acuracia: 0.8095 - precisão: 0.6262 - recall: 0.5906 - auc: 0.8811 - f1_score: 0.6071 - val_loss: 0.6681 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9205 - val_f1_score: 0.6496 - lr: 1.5849e-38
# Epoch 89/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7876 - acuracia: 0.8116 - precisão: 0.6303 - recall: 0.5961 - auc: 0.8831 - f1_score: 0.6123 - val_loss: 0.6680 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9205 - val_f1_score: 0.6496 - lr: 6.3096e-39
# Epoch 90/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7681 - acuracia: 0.8187 - precisão: 0.6451 - recall: 0.6111 - auc: 0.8882 - f1_score: 0.6273 - val_loss: 0.6684 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9204 - val_f1_score: 0.6495 - lr: 2.5119e-39
# Epoch 91/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7814 - acuracia: 0.8159 - precisão: 0.6392 - recall: 0.6051 - auc: 0.8859 - f1_score: 0.6221 - val_loss: 0.6687 - val_acuracia: 0.8413 - val_precisão: 0.7199 - val_recall: 0.5979 - val_auc: 0.9204 - val_f1_score: 0.6499 - lr: 1.0000e-39
# Epoch 92/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7932 - acuracia: 0.8101 - precisão: 0.6269 - recall: 0.5937 - auc: 0.8810 - f1_score: 0.6105 - val_loss: 0.6683 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9204 - val_f1_score: 0.6496 - lr: 3.9811e-40
# Epoch 93/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7911 - acuracia: 0.8100 - precisão: 0.6267 - recall: 0.5937 - auc: 0.8821 - f1_score: 0.6079 - val_loss: 0.6684 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9204 - val_f1_score: 0.6496 - lr: 1.5849e-40
# Epoch 94/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7760 - acuracia: 0.8173 - precisão: 0.6420 - recall: 0.6082 - auc: 0.8865 - f1_score: 0.6258 - val_loss: 0.6686 - val_acuracia: 0.8411 - val_precisão: 0.7195 - val_recall: 0.5968 - val_auc: 0.9204 - val_f1_score: 0.6491 - lr: 6.3096e-41
# Epoch 95/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7974 - acuracia: 0.8083 - precisão: 0.6230 - recall: 0.5903 - auc: 0.8802 - f1_score: 0.6072 - val_loss: 0.6686 - val_acuracia: 0.8411 - val_precisão: 0.7201 - val_recall: 0.5958 - val_auc: 0.9205 - val_f1_score: 0.6487 - lr: 2.5118e-41
# Epoch 96/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7746 - acuracia: 0.8134 - precisão: 0.6335 - recall: 0.6016 - auc: 0.8860 - f1_score: 0.6174 - val_loss: 0.6690 - val_acuracia: 0.8405 - val_precisão: 0.7183 - val_recall: 0.5958 - val_auc: 0.9204 - val_f1_score: 0.6478 - lr: 9.9997e-42
# Epoch 97/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.8019 - acuracia: 0.8049 - precisão: 0.6154 - recall: 0.5853 - auc: 0.8780 - f1_score: 0.6008 - val_loss: 0.6681 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9205 - val_f1_score: 0.6496 - lr: 3.9811e-42
# Epoch 98/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7833 - acuracia: 0.8111 - precisão: 0.6295 - recall: 0.5937 - auc: 0.8834 - f1_score: 0.6113 - val_loss: 0.6687 - val_acuracia: 0.8411 - val_precisão: 0.7195 - val_recall: 0.5968 - val_auc: 0.9204 - val_f1_score: 0.6491 - lr: 1.5849e-42
# Epoch 99/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7990 - acuracia: 0.8085 - precisão: 0.6230 - recall: 0.5922 - auc: 0.8809 - f1_score: 0.6060 - val_loss: 0.6687 - val_acuracia: 0.8408 - val_precisão: 0.7186 - val_recall: 0.5968 - val_auc: 0.9204 - val_f1_score: 0.6486 - lr: 6.3058e-43
# Epoch 100/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7679 - acuracia: 0.8139 - precisão: 0.6356 - recall: 0.5993 - auc: 0.8879 - f1_score: 0.6171 - val_loss: 0.6683 - val_acuracia: 0.8405 - val_precisão: 0.7183 - val_recall: 0.5958 - val_auc: 0.9206 - val_f1_score: 0.6481 - lr: 2.5083e-43
# Epoch 101/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7856 - acuracia: 0.8105 - precisão: 0.6277 - recall: 0.5948 - auc: 0.8832 - f1_score: 0.6107 - val_loss: 0.6684 - val_acuracia: 0.8408 - val_precisão: 0.7186 - val_recall: 0.5968 - val_auc: 0.9205 - val_f1_score: 0.6488 - lr: 9.9492e-44
# Epoch 102/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7712 - acuracia: 0.8183 - precisão: 0.6446 - recall: 0.6093 - auc: 0.8872 - f1_score: 0.6270 - val_loss: 0.6689 - val_acuracia: 0.8413 - val_precisão: 0.7199 - val_recall: 0.5979 - val_auc: 0.9204 - val_f1_score: 0.6499 - lr: 3.9236e-44
# Epoch 103/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7929 - acuracia: 0.8101 - precisão: 0.6269 - recall: 0.5937 - auc: 0.8820 - f1_score: 0.6105 - val_loss: 0.6688 - val_acuracia: 0.8408 - val_precisão: 0.7186 - val_recall: 0.5968 - val_auc: 0.9204 - val_f1_score: 0.6486 - lr: 1.5414e-44
# Epoch 104/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.8084 - acuracia: 0.8100 - precisão: 0.6276 - recall: 0.5900 - auc: 0.8781 - f1_score: 0.6074 - val_loss: 0.6689 - val_acuracia: 0.8408 - val_precisão: 0.7186 - val_recall: 0.5968 - val_auc: 0.9203 - val_f1_score: 0.6486 - lr: 7.0065e-45
# Epoch 105/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7939 - acuracia: 0.8150 - precisão: 0.6376 - recall: 0.6027 - auc: 0.8815 - f1_score: 0.6188 - val_loss: 0.6685 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9205 - val_f1_score: 0.6496 - lr: 2.8026e-45
# Epoch 106/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7862 - acuracia: 0.8108 - precisão: 0.6288 - recall: 0.5932 - auc: 0.8825 - f1_score: 0.6096 - val_loss: 0.6681 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9206 - val_f1_score: 0.6496 - lr: 1.4013e-45
# Epoch 107/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7879 - acuracia: 0.8135 - precisão: 0.6345 - recall: 0.5993 - auc: 0.8834 - f1_score: 0.6162 - val_loss: 0.6678 - val_acuracia: 0.8405 - val_precisão: 0.7183 - val_recall: 0.5958 - val_auc: 0.9207 - val_f1_score: 0.6481 - lr: 0.0000e+00
# Epoch 108/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7697 - acuracia: 0.8087 - precisão: 0.6247 - recall: 0.5882 - auc: 0.8855 - f1_score: 0.6049 - val_loss: 0.6679 - val_acuracia: 0.8403 - val_precisão: 0.7185 - val_recall: 0.5937 - val_auc: 0.9207 - val_f1_score: 0.6466 - lr: 0.0000e+00
# Epoch 109/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.8136 - acuracia: 0.8062 - precisão: 0.6191 - recall: 0.5845 - auc: 0.8772 - f1_score: 0.6024 - val_loss: 0.6680 - val_acuracia: 0.8403 - val_precisão: 0.7185 - val_recall: 0.5937 - val_auc: 0.9207 - val_f1_score: 0.6466 - lr: 0.0000e+00
# Epoch 110/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7803 - acuracia: 0.8147 - precisão: 0.6365 - recall: 0.6035 - auc: 0.8848 - f1_score: 0.6198 - val_loss: 0.6680 - val_acuracia: 0.8403 - val_precisão: 0.7174 - val_recall: 0.5958 - val_auc: 0.9207 - val_f1_score: 0.6476 - lr: 0.0000e+00
# Epoch 111/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7827 - acuracia: 0.8099 - precisão: 0.6271 - recall: 0.5911 - auc: 0.8826 - f1_score: 0.6080 - val_loss: 0.6682 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9206 - val_f1_score: 0.6496 - lr: 0.0000e+00
# Epoch 112/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7904 - acuracia: 0.8078 - precisão: 0.6215 - recall: 0.5911 - auc: 0.8814 - f1_score: 0.6063 - val_loss: 0.6686 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9205 - val_f1_score: 0.6496 - lr: 0.0000e+00
# Epoch 113/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7964 - acuracia: 0.8094 - precisão: 0.6248 - recall: 0.5945 - auc: 0.8805 - f1_score: 0.6094 - val_loss: 0.6689 - val_acuracia: 0.8411 - val_precisão: 0.7195 - val_recall: 0.5968 - val_auc: 0.9204 - val_f1_score: 0.6491 - lr: 0.0000e+00
# Epoch 114/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7824 - acuracia: 0.8130 - precisão: 0.6330 - recall: 0.5995 - auc: 0.8837 - f1_score: 0.6151 - val_loss: 0.6690 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9203 - val_f1_score: 0.6495 - lr: 0.0000e+00
# Epoch 115/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7758 - acuracia: 0.8150 - precisão: 0.6382 - recall: 0.6006 - auc: 0.8849 - f1_score: 0.6195 - val_loss: 0.6691 - val_acuracia: 0.8408 - val_precisão: 0.7186 - val_recall: 0.5968 - val_auc: 0.9203 - val_f1_score: 0.6486 - lr: 0.0000e+00
# Epoch 116/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.8147 - acuracia: 0.8071 - precisão: 0.6210 - recall: 0.5866 - auc: 0.8774 - f1_score: 0.6024 - val_loss: 0.6696 - val_acuracia: 0.8408 - val_precisão: 0.7186 - val_recall: 0.5968 - val_auc: 0.9202 - val_f1_score: 0.6486 - lr: 0.0000e+00
# Epoch 117/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7716 - acuracia: 0.8170 - precisão: 0.6422 - recall: 0.6053 - auc: 0.8866 - f1_score: 0.6224 - val_loss: 0.6694 - val_acuracia: 0.8408 - val_precisão: 0.7186 - val_recall: 0.5968 - val_auc: 0.9202 - val_f1_score: 0.6486 - lr: 0.0000e+00
# Epoch 118/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.8068 - acuracia: 0.8054 - precisão: 0.6166 - recall: 0.5853 - auc: 0.8786 - f1_score: 0.6012 - val_loss: 0.6692 - val_acuracia: 0.8408 - val_precisão: 0.7186 - val_recall: 0.5968 - val_auc: 0.9203 - val_f1_score: 0.6486 - lr: 0.0000e+00
# Epoch 119/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7849 - acuracia: 0.8104 - precisão: 0.6275 - recall: 0.5948 - auc: 0.8835 - f1_score: 0.6093 - val_loss: 0.6683 - val_acuracia: 0.8408 - val_precisão: 0.7186 - val_recall: 0.5968 - val_auc: 0.9206 - val_f1_score: 0.6488 - lr: 0.0000e+00
# Epoch 120/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7956 - acuracia: 0.8063 - precisão: 0.6200 - recall: 0.5824 - auc: 0.8795 - f1_score: 0.5998 - val_loss: 0.6689 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9205 - val_f1_score: 0.6496 - lr: 0.0000e+00
# Epoch 121/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7703 - acuracia: 0.8172 - precisão: 0.6428 - recall: 0.6051 - auc: 0.8871 - f1_score: 0.6221 - val_loss: 0.6690 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9204 - val_f1_score: 0.6496 - lr: 0.0000e+00
# Epoch 122/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7732 - acuracia: 0.8160 - precisão: 0.6404 - recall: 0.6024 - auc: 0.8855 - f1_score: 0.6197 - val_loss: 0.6689 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9205 - val_f1_score: 0.6496 - lr: 0.0000e+00
# Epoch 123/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7883 - acuracia: 0.8088 - precisão: 0.6239 - recall: 0.5919 - auc: 0.8817 - f1_score: 0.6078 - val_loss: 0.6686 - val_acuracia: 0.8413 - val_precisão: 0.7199 - val_recall: 0.5979 - val_auc: 0.9204 - val_f1_score: 0.6499 - lr: 0.0000e+00
# Epoch 124/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7794 - acuracia: 0.8155 - precisão: 0.6383 - recall: 0.6045 - auc: 0.8854 - f1_score: 0.6201 - val_loss: 0.6683 - val_acuracia: 0.8408 - val_precisão: 0.7186 - val_recall: 0.5968 - val_auc: 0.9206 - val_f1_score: 0.6488 - lr: 0.0000e+00
# Epoch 125/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7967 - acuracia: 0.8074 - precisão: 0.6210 - recall: 0.5890 - auc: 0.8801 - f1_score: 0.6041 - val_loss: 0.6682 - val_acuracia: 0.8405 - val_precisão: 0.7183 - val_recall: 0.5958 - val_auc: 0.9207 - val_f1_score: 0.6481 - lr: 0.0000e+00
# Epoch 126/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.8095 - acuracia: 0.8060 - precisão: 0.6183 - recall: 0.5856 - auc: 0.8776 - f1_score: 0.6006 - val_loss: 0.6682 - val_acuracia: 0.8405 - val_precisão: 0.7188 - val_recall: 0.5947 - val_auc: 0.9207 - val_f1_score: 0.6475 - lr: 0.0000e+00
# Epoch 127/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.8079 - acuracia: 0.8080 - precisão: 0.6229 - recall: 0.5879 - auc: 0.8797 - f1_score: 0.6042 - val_loss: 0.6681 - val_acuracia: 0.8408 - val_precisão: 0.7186 - val_recall: 0.5968 - val_auc: 0.9206 - val_f1_score: 0.6488 - lr: 0.0000e+00
# Epoch 128/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7800 - acuracia: 0.8132 - precisão: 0.6330 - recall: 0.6016 - auc: 0.8841 - f1_score: 0.6179 - val_loss: 0.6685 - val_acuracia: 0.8413 - val_precisão: 0.7199 - val_recall: 0.5979 - val_auc: 0.9204 - val_f1_score: 0.6499 - lr: 0.0000e+00
# Epoch 129/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7949 - acuracia: 0.8119 - precisão: 0.6310 - recall: 0.5966 - auc: 0.8808 - f1_score: 0.6137 - val_loss: 0.6683 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9205 - val_f1_score: 0.6496 - lr: 0.0000e+00
# Epoch 130/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7812 - acuracia: 0.8107 - precisão: 0.6281 - recall: 0.5953 - auc: 0.8838 - f1_score: 0.6127 - val_loss: 0.6682 - val_acuracia: 0.8408 - val_precisão: 0.7186 - val_recall: 0.5968 - val_auc: 0.9206 - val_f1_score: 0.6488 - lr: 0.0000e+00
# Epoch 131/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7891 - acuracia: 0.8111 - precisão: 0.6295 - recall: 0.5937 - auc: 0.8818 - f1_score: 0.6106 - val_loss: 0.6684 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9205 - val_f1_score: 0.6496 - lr: 0.0000e+00
# Epoch 132/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7866 - acuracia: 0.8110 - precisão: 0.6288 - recall: 0.5951 - auc: 0.8830 - f1_score: 0.6115 - val_loss: 0.6682 - val_acuracia: 0.8411 - val_precisão: 0.7195 - val_recall: 0.5968 - val_auc: 0.9205 - val_f1_score: 0.6491 - lr: 0.0000e+00
# Epoch 133/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.8095 - acuracia: 0.8061 - precisão: 0.6177 - recall: 0.5887 - auc: 0.8784 - f1_score: 0.6032 - val_loss: 0.6684 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9204 - val_f1_score: 0.6495 - lr: 0.0000e+00
# Epoch 134/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7782 - acuracia: 0.8092 - precisão: 0.6250 - recall: 0.5916 - auc: 0.8834 - f1_score: 0.6090 - val_loss: 0.6684 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9204 - val_f1_score: 0.6495 - lr: 0.0000e+00
# Epoch 135/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7863 - acuracia: 0.8083 - precisão: 0.6233 - recall: 0.5895 - auc: 0.8821 - f1_score: 0.6057 - val_loss: 0.6684 - val_acuracia: 0.8408 - val_precisão: 0.7186 - val_recall: 0.5968 - val_auc: 0.9204 - val_f1_score: 0.6486 - lr: 0.0000e+00
# Epoch 136/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.8141 - acuracia: 0.8040 - precisão: 0.6139 - recall: 0.5819 - auc: 0.8769 - f1_score: 0.5970 - val_loss: 0.6688 - val_acuracia: 0.8408 - val_precisão: 0.7186 - val_recall: 0.5968 - val_auc: 0.9203 - val_f1_score: 0.6486 - lr: 0.0000e+00
# Epoch 137/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7670 - acuracia: 0.8185 - precisão: 0.6449 - recall: 0.6098 - auc: 0.8879 - f1_score: 0.6271 - val_loss: 0.6689 - val_acuracia: 0.8408 - val_precisão: 0.7186 - val_recall: 0.5968 - val_auc: 0.9203 - val_f1_score: 0.6486 - lr: 0.0000e+00
# Epoch 138/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7765 - acuracia: 0.8130 - precisão: 0.6332 - recall: 0.5987 - auc: 0.8847 - f1_score: 0.6155 - val_loss: 0.6688 - val_acuracia: 0.8413 - val_precisão: 0.7199 - val_recall: 0.5979 - val_auc: 0.9204 - val_f1_score: 0.6499 - lr: 0.0000e+00
# Epoch 139/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7886 - acuracia: 0.8133 - precisão: 0.6345 - recall: 0.5974 - auc: 0.8833 - f1_score: 0.6160 - val_loss: 0.6685 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9205 - val_f1_score: 0.6496 - lr: 0.0000e+00
# Epoch 140/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7829 - acuracia: 0.8108 - precisão: 0.6283 - recall: 0.5958 - auc: 0.8832 - f1_score: 0.6131 - val_loss: 0.6688 - val_acuracia: 0.8411 - val_precisão: 0.7201 - val_recall: 0.5958 - val_auc: 0.9205 - val_f1_score: 0.6487 - lr: 0.0000e+00
# Epoch 141/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.8005 - acuracia: 0.8063 - precisão: 0.6190 - recall: 0.5864 - auc: 0.8796 - f1_score: 0.6017 - val_loss: 0.6686 - val_acuracia: 0.8411 - val_precisão: 0.7190 - val_recall: 0.5979 - val_auc: 0.9205 - val_f1_score: 0.6496 - lr: 0.0000e+00
# Epoch 142/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7969 - acuracia: 0.8092 - precisão: 0.6245 - recall: 0.5937 - auc: 0.8793 - f1_score: 0.6077 - val_loss: 0.6684 - val_acuracia: 0.8403 - val_precisão: 0.7179 - val_recall: 0.5947 - val_auc: 0.9207 - val_f1_score: 0.6472 - lr: 0.0000e+00
# Epoch 143/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7806 - acuracia: 0.8121 - precisão: 0.6317 - recall: 0.5956 - auc: 0.8846 - f1_score: 0.6136 - val_loss: 0.6679 - val_acuracia: 0.8405 - val_precisão: 0.7188 - val_recall: 0.5947 - val_auc: 0.9208 - val_f1_score: 0.6475 - lr: 0.0000e+00
# Epoch 144/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7763 - acuracia: 0.8157 - precisão: 0.6391 - recall: 0.6037 - auc: 0.8851 - f1_score: 0.6204 - val_loss: 0.6679 - val_acuracia: 0.8403 - val_precisão: 0.7185 - val_recall: 0.5937 - val_auc: 0.9208 - val_f1_score: 0.6466 - lr: 0.0000e+00
# Epoch 145/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7732 - acuracia: 0.8150 - precisão: 0.6376 - recall: 0.6022 - auc: 0.8859 - f1_score: 0.6202 - val_loss: 0.6679 - val_acuracia: 0.8405 - val_precisão: 0.7188 - val_recall: 0.5947 - val_auc: 0.9208 - val_f1_score: 0.6473 - lr: 0.0000e+00
# Epoch 146/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.8072 - acuracia: 0.8036 - precisão: 0.6138 - recall: 0.5782 - auc: 0.8782 - f1_score: 0.5963 - val_loss: 0.6681 - val_acuracia: 0.8405 - val_precisão: 0.7183 - val_recall: 0.5958 - val_auc: 0.9207 - val_f1_score: 0.6479 - lr: 0.0000e+00
# Epoch 147/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.8036 - acuracia: 0.8100 - precisão: 0.6268 - recall: 0.5935 - auc: 0.8797 - f1_score: 0.6082 - val_loss: 0.6685 - val_acuracia: 0.8400 - val_precisão: 0.7170 - val_recall: 0.5947 - val_auc: 0.9207 - val_f1_score: 0.6469 - lr: 0.0000e+00
# Epoch 148/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.8003 - acuracia: 0.8088 - precisão: 0.6236 - recall: 0.5929 - auc: 0.8792 - f1_score: 0.6073 - val_loss: 0.6683 - val_acuracia: 0.8400 - val_precisão: 0.7170 - val_recall: 0.5947 - val_auc: 0.9207 - val_f1_score: 0.6469 - lr: 0.0000e+00
# Epoch 149/150
# 65/65 [==============================] - 67s 1s/step - loss: 0.7940 - acuracia: 0.8115 - precisão: 0.6299 - recall: 0.5961 - auc: 0.8817 - f1_score: 0.6121 - val_loss: 0.6683 - val_acuracia: 0.8408 - val_precisão: 0.7186 - val_recall: 0.5968 - val_auc: 0.9205 - val_f1_score: 0.6488 - lr: 0.0000e+00
# Epoch 150/150
# 65/65 [==============================] - 68s 1s/step - loss: 0.7971 - acuracia: 0.8079 - precisão: 0.6231 - recall: 0.5856 - auc: 0.8797 - f1_score: 0.6030 - val_loss: 0.6684 - val_acuracia: 0.8411 - val_precisão: 0.7195 - val_recall: 0.5968 - val_auc: 0.9206 - val_f1_score: 0.6490 - lr: 0.0000e+00
#
# Keras CNN #1C - acuracia: 0.8581649661064148

# %%
Train_Val_Plot(history.history['acuracia'],history.history['val_acuracia'],
            history.history['loss'],history.history['val_loss'],
            history.history['auc'],history.history['val_auc'],
            history.history['precisão'],history.history['val_precisão'],
            history.history['recall'],history.history['val_recall'],
            history.history['f1_score'],history.history['val_f1_score']
            )

# %%
test_scores = model.evaluate(test_data, test_labels)

print("Acuracia = ", test_scores[1])
print("Precisão = ", test_scores[2])
print("Recall = ", test_scores[3])
print("AUC = ", test_scores[4])
print("F1_score = ", test_scores[5])
# Out:
# 38/38 [==============================] - 4s 98ms/step - loss: 0.6313 - acuracia: 0.8582 - precisão: 0.7565 - recall: 0.6380 - auc: 0.9320 - f1_score: 0.6955
# Acuracia =  0.8581649661064148
# Precisão =  0.7564870119094849
# Recall =  0.6380471587181091
# AUC =  0.9319968819618225
# F1_score =  0.6954604983329773

# %%
pred_labels = model.predict(test_data)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
#Como os rótulos são arrays softmax, precisamos arredondar para tê-los na forma de 0s e 1s,
#semelhante aos test_labels
def roundoff(arr):
    arr[np.argwhere(arr != arr.max())] = 0
    arr[np.argwhere(arr == arr.max())] = 1
    return arr

for labels in pred_labels:
    labels = roundoff(labels)

print(classification_report(test_labels, pred_labels, target_names=CLASSES))
# Out:
#               precision    recall  f1-score   support
#
#     MONOCYTE       0.00      0.00      0.00         0
#   EOSINOPHIL       0.00      0.00      0.00         0
#   NEUTROPHIL       0.68      0.75      0.72       571
#   LYMPHOCYTE       0.75      0.68      0.71       617
#
#    micro avg       0.71      0.71      0.71      1188
#    macro avg       0.36      0.36      0.36      1188
# weighted avg       0.72      0.71      0.71      1188
#  samples avg       0.71      0.71      0.71      1188
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#Plotar a matriz de confusão para entender a classificação em detalhes

pred_ls = np.argmax(pred_labels, axis=1)
test_ls = np.argmax(test_labels, axis=1)

conf_arr = confusion_matrix(test_ls, pred_ls)

plt.figure(figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

ax = sns.heatmap(conf_arr, cmap='Greens', annot=True, fmt='d', xticklabels= CLASSES,
                yticklabels=CLASSES)

plt.title('Células Snaguineas')
plt.xlabel('Predição')
plt.ylabel('Verdadeiro')
plt.show(ax)
